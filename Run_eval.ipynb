# %% [markdown]
# **FAST MRI**

# %%
'''
function ClickConnect() {
    var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); 
    buttons.forEach(function(btn) { 
        btn.click(); 
    }); 
    console.log("10분마다 자동 재연결"); 
    document.querySelector("colab-toolbar-button#connect").click(); 
} 
setInterval(ClickConnect,1000*60*10);
'''
# Out:
# '\nfunction ClickConnect() {\n    var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); \n    buttons.forEach(function(btn) { \n        btn.click(); \n    }); \n    console.log("10분마다 자동 재연결"); \n    document.querySelector("colab-toolbar-button#connect").click(); \n} \nsetInterval(ClickConnect,1000*60*10);\n'

# %% [markdown]
# mount google drive to colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# path setting

# %%
# %cd /content/drive/MyDrive/SNU_Challenge/Code/
# Out:
# /content/drive/MyDrive/SNU_Challenge/Code

# %% [markdown]
# **U Net**

# %% [markdown]
# evaluate

# %%
# !python3 evaluate.py \
-g 0 \
-b 4 \
-n 'test_Unet' \
-p '../Data/image_Leaderboard/' \
--in-chans 1 \
--out-chans 1 \
--input_key 'image_input'
# Out:
# ../result/test_Unet/reconstructions_forward
# Current cuda device  0
# 7 0.08021024450766052
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# calculate SSIM

# %%
# !python3 leaderboard_eval.py \
-g 0 \
-lp '../Data/image_Leaderboard/' \
-yp '../result/test_Unet/reconstructions_forward/' \
--output_key 'reconstruction'
# Out:
# Leaderboard Dataset SSIM : 0.9070

# %% [markdown]
# **U Net advanced**

# %% [markdown]
# evaluate

# %%
# !python3 evaluate.py \
-g 0 \
-b 4 \
-n 'test_Unet_advanced' \
-p '../Data/image_Leaderboard/' \
--in-chans 1 \
--out-chans 1 \
--input_key 'image_input'
# Out:
# ../result/test_Unet_advanced/reconstructions_forward
# Current cuda device  0
# 5 0.1152816717512892
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# calculate SSIM

# %%
# !python3 leaderboard_eval.py \
-g 0 \
-lp '../Data/image_Leaderboard/' \
-yp '../result/test_Unet_advanced/reconstructions_forward/' \
--output_key 'reconstruction'
# Out:
# Leaderboard Dataset SSIM : 0.9355

# %% [markdown]
# **Res Net**

# %% [markdown]
# evaluate

# %%
# !python3 evaluate.py \
-g 0 \
-b 4 \
-n 'test_Resnet' \
-p '../Data/image_Leaderboard/' \
--in-chans 1 \
--out-chans 1 \
--input_key 'image_input'
# Out:
# ../result/test_Resnet/reconstructions_forward
# Current cuda device  0
# 5 0.06591040690535478
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# calculate SSIM

# %%
# !python3 leaderboard_eval.py \
-g 0 \
-lp '../Data/image_Leaderboard/' \
-yp '../result/test_Resnet/reconstructions_forward/' \
--output_key 'reconstruction'
# Out:
# Leaderboard Dataset SSIM : 0.9141

# %% [markdown]
# **SR Res Net**

# %% [markdown]
# evaluate

# %%
# !python3 evaluate.py \
-g 0 \
-b 4 \
-n 'test_SRResnet' \
-p '../Data/image_Leaderboard/' \
--in-chans 1 \
--out-chans 1 \
--input_key 'image_input'
# Out:
# ../result/test_SRResnet/reconstructions_forward
# Current cuda device  0
# 2 0.1018537950277243
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# calculate SSIM

# %%
# !python3 leaderboard_eval.py \
-g 0 \
-lp '../Data/image_Leaderboard/' \
-yp '../result/test_SRResnet/reconstructions_forward/' \
--output_key 'reconstruction'
# Out:
# Leaderboard Dataset SSIM : 0.9370
